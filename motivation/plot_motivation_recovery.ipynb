# %% [markdown]
# **Figure: Existing recovery substrates discard independent work.** Controlled
# effect-DAG sweep (16/32/64 calls) over checkpoint-style temporal rollback
# (Crab/DeltaBox), session/branch abort (YoloFS/BranchFS), and command undo
# without dependency tracking. AgentTX is omitted. At 64 calls, checkpoint-style
# recovery retains only 41% of independent work; session/branch abort retains
# none; command undo without deps removes only 4% of invalid descendants.

# %%
# Existing recovery substrates only — no AgentTX series.
import runpy
from pathlib import Path
cwd = Path.cwd()
script = cwd / 'plot_motivation_recovery.py'
if not script.exists():
    script = cwd / 'motivation' / 'plot_motivation_recovery.py'
runpy.run_path(str(script), run_name='__main__')
