# %% [markdown]
# **Deprecated.** The fixed-length Optimization bar chart was removed from the
# paper: it does not show multi-length overhead and duplicates panel (a) of
# `FIG-Motivation-Scaling`. Use `plot_scaling.ipynb` / `plot_motivation_scaling.ipynb`.

# %%
print('Use plot_scaling.ipynb for FIG-Motivation-Scaling')
